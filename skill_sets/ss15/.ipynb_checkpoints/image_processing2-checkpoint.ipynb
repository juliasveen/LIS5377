# %% [markdown]
# # Python Image Processing
#
# **Developer:** Julia Sveen
#
# **Course:** AI Applications
#
# **Semester:** Spring 2026
#
# **Program Requirements:**
# 1. Get data
# 2. Prepare data
# 3. Display data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
import os
print("Available images:")
for dirname, _filenames in os.walk('img'):
    for filename in filenames:
        print(os.path.join(dirname,filename))
# Out:
# Available images:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 import os
#       2 print("Available images:")
# ----> 3 for dirname, _filenames in os.walk('img'):
#       4     for filename in filenames:
#       5         print(os.path.join(dirname,filename))
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# ## List all video files

# %%
print("Available videos: ")
for dirname, _, filenames in os.walk('vids'):
    for filename in filenames:
        print(os.path.join(dirname,filename))
# Out:
# Available videos:
# vids\Background-Subtraction-Tutorial_merged.mp4
# vids\Background_Subtraction_Tutorial_frame.mp4

# %%
image=cv2.imread('img/WaldoBeach.jpg')
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

plt.figure(figsize=(20,20))
plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(image)

kernel_sharpening = np.array([[-1,-1,-1],
                              [-1,9,-1],
                              [-1,-1,-1]])
sharpened=cv2.filter2D(image,-1,kernel_sharpening)

plt.subplot(1,2,2)
plt.title("Image Sharpening")
plt.imshow(sharpened)
plt.show()

# %% [markdown]
# ## Thresholding Images

# %%
image=cv2.imread
