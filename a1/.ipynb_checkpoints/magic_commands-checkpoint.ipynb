# %% [markdown]
# # Magic Commands

# %%
# magic commands:
    # special cmds that helo with running and analyzing data in jupyter notebooks
    # single % for one line of code, or double %% for several lines

# %% [markdown]
# ## 1. List all magic commands: %lsmagic

# %%
# %lsmagic

# %%
# example lime magic
# %ls

# %% [markdown]
# ## 2. Run file: %run

# %%
# example run file
# %run hello.py

# %% [markdown]
# ## 3. Load file: %load
#
# **Note**: %run runs file, %load loads file into cell

# %%
# %load hello.py
# note: file was loaded into cell, then cell code was modified

# create function
def hello_test():
    print("Hello, test!")

hello_test()

# %% [markdown]
# ## 4. Return execution time: %%time
#
# **Note**: %%time is 'cell magic' and **must be** first line in Jupyter notebook cell

# %%
# %%time
import random
for i in range(0,1000000):
    random.random

# display time generate 1,000,000 random numbers
# note: placing these comments above code generates an error

# %% [markdown]
# ## 5. List all variables: %who

# %%
# example
my_var1 = 1
my_var2 = 'hello'
my_var3 = True

# %%
# list all variables
# %who

# %%
# list specific variable
# %who bool

# %% [markdown]
# ## 6. Display variable details: %pinfo

# %%
# example (note: includes strength of spring
# %pinfo my_var2

# %% [markdown]
# ## 7. Get/set environmental variables: %env

# %%
# example: list environmental variables
# %env

# %%
# add new environmental variable called MY_VAR: 
# %env MY_VAR=Users/someuser

# %%
# check specific environment variable value
# %env JAVA_HOME
