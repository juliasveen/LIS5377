# %% [markdown]
# # Run python files (.py) in Jupyter Lab
#
# ## Run Jupyter Lab in directory containing .py files
#
# ### Run cells with commands below.

# %%
# Note: magic functions start with a percent sign (%) or double percent sign (%%)
# single percent sign will act as only one line
# double signs can spread over multiple lines, DO NOT support assignments

# %%
# 1. %run (runs script as if executing from cmd)
# create test.py file that prints "Hello World!", in some directory in this notebook
# %run test.py

# %%
# Note: can also print timing -t and run multiple times -N<N>
# %run -t -N3 test.py

# %%
# 2. import:
# combines 2 operation: searches for named module, then binds results of search to name in local scope
# Note: DO NOT include .py 
import test

# %%
# 3. %load loads file contents into code cell

# %%
# %load test.py

# %% [markdown]
# ### Demo: %%writefile (use cell below)
#
#     1. load file into cell below (**load test.py**)
#     2. make changes to cell, then run
#     3. open file in text editor
#     4. place **writefile test.py** at top of loaded cell, **comment out %load**, then run again
#     5. note: changes now take place
#
# **Note**: File will be overwritten unless -a flag is specified

# %%
# %%writefile test.py
# %load test.py
print("Hello MY world!")

# %%
# ! bang operator accesses underlying shell
# calling windows notepad
# !notepad demo.py
